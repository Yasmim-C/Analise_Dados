# %%
import numpy as np

np.__version__
# Out:
# '2.5.3'

# %%
arr =np.array([1,2,3,4,5])
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
soma = arr + 20
print("Soma do array com 20:", soma)
# Out:
# Soma do array com 20: [21 22 23 24 25]

# %%
media = np.mean(arr)
print("Média do array:", media)
# Out:
# Média do array: 3.0
