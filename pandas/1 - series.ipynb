# %% [markdown]
# # Utilizando Estruturas series

# %%
import pandas as pd

# %%
dados = [10, 20, 30, 40, 50]
serie = pd.Series(dados)
serie
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
type(serie)
# Out:
# pandas.Series

# %%
# Criando uma series com dados de vendas mensais
vendas_mensais = pd.Series(
    [2000, 2500, 3000, 2800, 3500, 4000, 4500, 5000, 4800, 5200, 7000, 8000],
    index=['Jan', 'Fev', 'Mar', 'Abr','Mai','Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
)

# %%
vendas_mensais
# Out:
# Jan    2000
# Fev    2500
# Mar    3000
# Abr    2800
# Mai    3500
# Jun    4000
# Jul    4500
# Ago    5000
# Set    4800
# Out    5200
# Nov    7000
# Dez    8000
# dtype: int64

# %%
# Calcular e exibir a média das vendas

media_vendas = vendas_mensais.mean()
media_vendas
# Out:
# np.float64(4358.333333333333)

# %%
# Mês com maior venda
mes_maior_venda = vendas_mensais.idxmax()
mes_maior_venda
# Out:
# 'Dez'

# %%
# Mostrar vendas acima da média

vendas_acima_media = vendas_mensais[vendas_mensais > media_vendas]
vendas_acima_media
# Out:
# Jul    4500
# Ago    5000
# Set    4800
# Out    5200
# Nov    7000
# Dez    8000
# dtype: int64
